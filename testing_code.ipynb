# %%
# %run text_input_8puzzle.py -setState "12b 345 678" -printState -tablePrintState
# Out:
# Current puzzle state:
# 12b 345 678
#
# Current State
# ----------
# | 1 | 2 | 0 |
# ----------
# | 3 | 4 | 5 |
# ----------
# | 6 | 7 | 8 |

# %%
# %run text_input_8puzzle.py -setState "123 4b5 678" -move "left" -tablePrintState
# Out:
# The length of the state is incorrect
# Character is not valid '
# Character is not valid '
# This move is not allowed
#
# Current State
# ----------
# | 0 | 1 | 2 |
# ----------
# | 4 | 0 | 5 |
# ----------
# | 6 | 7 | 8 |

# %%
# %run text_input_8puzzle.py -randomizeState 0 -printState -tablePrintState
# Out:
# Current puzzle state:
# b12 345 678
#
# Current State
# ----------
# | 0 | 1 | 2 |
# ----------
# | 3 | 4 | 5 |
# ----------
# | 6 | 7 | 8 |

# %%
# %run text_input_8puzzle.py -randomizeState 15 -printState -tablePrintState
# Out:
# Current puzzle state:
# 125 34b 678
#
# Current State
# ----------
# | 1 | 2 | 5 |
# ----------
# | 3 | 4 | 0 |
# ----------
# | 6 | 7 | 8 |

# %%
# %run text_input_8puzzle.py -setState "742 b86 315" -solveAStar h1 -maxNodes 10000 -tablePrintSolution
# Out:
# The length of the state is incorrect
# Character is not valid '
# Character is not valid '

# %%
# %run text_input_8puzzle.py -setState "321 574 6b8" -solveAStar h2 -tablePrintSolution
# Out:
# Solution is below
# Solution Length:  13
# Solution Path ['start', 'up', 'up', 'right', 'down', 'left', 'left', 'up', 'right', 'right', 'down', 'left', 'up', 'left', 'goal']
# Total nodes generated: 213
#
# Starting State
# -------------
# | 3 | 2 | 1 |
# -------------
# | 5 | 7 | 4 |
# -------------
# | 6 | 0 | 8 |
#
#  Current node depth:  1
# -------------
# | 3 | 2 | 1 |
# -------------
# | 5 | 0 | 4 |
# -------------
# | 6 | 7 | 8 |
#
#  Current node depth:  2
# -------------
# | 3 | 0 | 1 |
# -------------
# | 5 | 2 | 4 |
# -------------
# | 6 | 7 | 8 |
#
#  Current node depth:  3
# -------------
# | 3 | 1 | 0 |
# -------------
# | 5 | 2 | 4 |
# -------------
# | 6 | 7 | 8 |
#
#  Current node depth:  4
# -------------
# | 3 | 1 | 4 |
# -------------
# | 5 | 2 | 0 |
# -------------
# | 6 | 7 | 8 |
#
#  Current node depth:  5
# -------------
# | 3 | 1 | 4 |
# -------------
# | 5 | 0 | 2 |
# -------------
# | 6 | 7 | 8 |
#
#  Current node depth:  6
# -------------
# | 3 | 1 | 4 |
# ...

# %%
# %run text_input_8puzzle.py -setState "321 574 6b8" -solveBeam 10 -tablePrintSolution
# Out:
# Solution is below
# Solution Length:  31
# Solution Path ['start', 'up', 'right', 'up', 'left', 'down', 'left', 'up', 'right', 'down', 'right', 'up', 'left', 'down', 'right', 'up', 'left', 'left', 'down', 'right', 'up', 'right', 'down', 'left', 'left', 'up', 'right', 'down', 'right', 'up', 'left', 'left', 'goal']
# Total nodes generated: 418
#
# Starting State
# -------------
# | 3 | 2 | 1 |
# -------------
# | 5 | 7 | 4 |
# -------------
# | 6 | 0 | 8 |
#
#  The current depth is:  1
# -------------
# | 3 | 2 | 1 |
# -------------
# | 5 | 0 | 4 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  2
# -------------
# | 3 | 2 | 1 |
# -------------
# | 5 | 4 | 0 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  3
# -------------
# | 3 | 2 | 0 |
# -------------
# | 5 | 4 | 1 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  4
# -------------
# | 3 | 0 | 2 |
# -------------
# | 5 | 4 | 1 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  5
# ...

# %%
# %run text_input_8puzzle.py -setState "321 574 6b8" -solveBeam 1000 -tablePrintSolution
# Out:
# Solution is below
# Solution Length:  13
# Solution Path ['start', 'up', 'up', 'right', 'down', 'left', 'left', 'up', 'right', 'right', 'down', 'left', 'up', 'left', 'goal']
# Total nodes generated: 3453
#
# Starting State
# -------------
# | 3 | 2 | 1 |
# -------------
# | 5 | 7 | 4 |
# -------------
# | 6 | 0 | 8 |
#
#  The current depth is:  1
# -------------
# | 3 | 2 | 1 |
# -------------
# | 5 | 0 | 4 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  2
# -------------
# | 3 | 0 | 1 |
# -------------
# | 5 | 2 | 4 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  3
# -------------
# | 3 | 1 | 0 |
# -------------
# | 5 | 2 | 4 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  4
# -------------
# | 3 | 1 | 4 |
# -------------
# | 5 | 2 | 0 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  5
# -------------
# | 3 | 1 | 4 |
# -------------
# | 5 | 0 | 2 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  6
# -------------
# ...

# %%
# %run text_input_8puzzle.py -randomizeState 10 -solveAStar h1 -maxNodes 3000 -tablePrintSolution
# Out:
# Solution is below
# Solution Length:  4
# Solution Path ['start', 'right', 'up', 'left', 'left', 'goal']
# Total nodes generated: 12
#
# Starting State
# -------------
# | 1 | 2 | 5 |
# -------------
# | 3 | 0 | 4 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  1
# -------------
# | 1 | 2 | 5 |
# -------------
# | 3 | 4 | 0 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  2
# -------------
# | 1 | 2 | 0 |
# -------------
# | 3 | 4 | 5 |
# -------------
# | 6 | 7 | 8 |
#
#  The current depth is:  3
# -------------
# | 1 | 0 | 2 |
# -------------
# | 3 | 4 | 5 |
# -------------
# | 6 | 7 | 8 |
# We have reached the goal
# -------------
# | 0 | 1 | 2 |
# -------------
# | 3 | 4 | 5 |
# -------------
# | 6 | 7 | 8 |

# %%
# %run text_input_8puzzle.py -randomizeState 10 -solveBeam 100 -maxNodes 3000 -tablePrintSolution
# Out:
# Solution is below
# Solution Length:  4
# Solution Path ['start', 'right', 'up', 'left', 'left', 'goal']
# Total nodes generated: 33
#
# Starting State
# -------------
# | 1 | 2 | 5 |
# -------------
# | 3 | 0 | 4 |
# -------------
# | 6 | 7 | 8 |
#
#  Current node depth:  1
# -------------
# | 1 | 2 | 5 |
# -------------
# | 3 | 4 | 0 |
# -------------
# | 6 | 7 | 8 |
#
#  Current node depth:  2
# -------------
# | 1 | 2 | 0 |
# -------------
# | 3 | 4 | 5 |
# -------------
# | 6 | 7 | 8 |
#
#  Current node depth:  3
# -------------
# | 1 | 0 | 2 |
# -------------
# | 3 | 4 | 5 |
# -------------
# | 6 | 7 | 8 |
# We have reached the goal
# -------------
# | 0 | 1 | 2 |
# -------------
# | 3 | 4 | 5 |
# -------------
# | 6 | 7 | 8 |

# %%
# %run text_input_8puzzle.py -readCommands "randomize_solve_beam.txt"
# Out:
# Current puzzle state:
# 2b3 615 748
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\Case Western Reserve Documents\CSDS 391\Project1\text_input_8puzzle.py:92, in <module>
#      91 try:
# ---> 92 	max_nodes_index = arguments.index("maxNodes")
#      93 	max_nodes = int(arguments[max_nodes_index])
#
# ValueError: 'maxNodes' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Desktop\Case Western Reserve Documents\CSDS 391\Project1\text_input_8puzzle.py:96, in <module>
#      94 		puzzle.solve_beam(k = k, max_nodes = max_nodes)
#      95 	except:
# ---> 96 		puzzle.solve_beam(k = k)
#      98 elif argument == "printState":
#      99 	print("Current puzzle state:")
#
# ...

# %%
# %run text_input_8puzzle.py -readCommands "randomize_solve_Astar.txt"
# Out:
# Solution is below
# Solution Length:  2
# Solution Path ['start', 'left', 'left', 'goal']
# Total nodes generated: 5

# %%
# %run text_input_8puzzle.py -readCommands "P1-test.txt"
# Out:
# Current puzzle state:
# b12 345 678
# This move is not allowed
# This move is not allowed
# The length of the state is incorrect
# Character is not valid p
# Character is not valid "
# Current puzzle state:
# b12 345 345
# This move is not allowed

# %%
# %run text_input_8puzzle.py -readCommands "randomize_solve_beam_2.txt"
# Out:
# Current puzzle state:
# 3b2 615 748
# Solution is below
# Solution Length:  5
# Solution Path ['start', 'down', 'down', 'left', 'up', 'up', 'goal']
# Total nodes generated: 50

# %%
# %run text_input_8puzzle.py -readCommands "randomize_print_table.txt"
# Out:
# Current puzzle state:
# 12b 345 678

# %%
# %run text_input_8puzzle.py -randomizeState 10000 -printState -maxNodes 10000 -solveBeam 10
# Out:
# Current puzzle state:
# 482 713 b56
# Solution is below
# Solution Length:  36
# Solution Path ['start', 'up', 'up', 'right', 'down', 'right', 'down', 'left', 'left', 'up', 'right', 'right', 'down', 'left', 'up', 'left', 'down', 'right', 'right', 'up', 'left', 'left', 'up', 'right', 'down', 'left', 'down', 'right', 'up', 'right', 'down', 'left', 'left', 'up', 'right', 'up', 'left', 'goal']
# Total nodes generated: 491
